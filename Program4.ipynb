# %%
# Question=4
import pandas as pd
df=pd.read_csv("Advertising.csv")
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.drop(["Unnamed: 0"],axis='columns',inplace=True)
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
import matplotlib.pyplot as plt
myplt=plt.figure(figsize=(10,8))
ax1=myplt.add_subplot(2,2,1)
ax1.scatter(df['TV'],df['sales'],c='green')
plt.xlabel("Money spent on TV ads")
plt.ylabel("sales")
plt.show()

# %%
myplt=plt.figure(figsize=(10,8))
ax2=myplt.add_subplot(2,2,1)
ax2.scatter(df['radio'],df['sales'],c='red')
plt.xlabel("Money spent on radio ads")
plt.ylabel("sales")
plt.show()

# %%
myplt=plt.figure(figsize=(10,8))
ax3=myplt.add_subplot(2,2,1)
ax3.scatter(df['newspaper'],df['sales'],c='blue')
plt.xlabel("Money spent on newspaper ads")
plt.ylabel("sales")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.model_selection import train_test_split


x=df['TV'].values.reshape(-1,1)
y=df['sales'].values.reshape(-1,1)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print("slope (m) :",model.coef_[0][0])
print("intercept (c) :",model.intercept_[0])
print("the linear model between TV vs sales is y={:.3f}+ {:.3f}x".format(model.intercept_[0],model.coef_[0][0]))
# Out:
# slope (m) : 0.04644389369483612
# intercept (c) : 7.240784412145088
# the linear model between TV vs sales is y=7.241+ 0.046x

# %%
predictions=model.predict(x_test)
plt.figure(figsize=(10,8))
plt.scatter(x_train,y_train,c="green")
plt.plot(x_test,predictions,c="black")
plt.xlabel("Money spent on Tv ads")
plt.ylabel("sales")
plt.show()

# %%
import numpy as np
mse=mean_squared_error(y_test,predictions)
print(f"Mean Squared Error:",mse)
r2=r2_score(y_test,predictions)
print(f"R2-Score:",r2)
rmse=np.sqrt(mse)
print(f"Root Mean Squared Error:",rmse)
# Out:
# Mean Squared Error: 10.264707108827668
# R2-Score: 0.6858570552557655
# Root Mean Squared Error: 3.2038581599109017

# %%
x=df['radio'].values.reshape(-1,1)
y=df['sales'].values.reshape(-1,1)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print("slope (m) :",model.coef_[0][0])
print("intercept (c) :",model.intercept_[0])
print("the linear model between radio vs sales is y={:.3f}+ {:.3f}x".format(model.intercept_[0],model.coef_[0][0]))
# Out:
# slope (m) : 0.20016956669066857
# intercept (c) : 9.433784521525165
# the linear model between radio vs sales is y=9.434+ 0.200x

# %%
predictions=model.predict(x_test)
plt.figure(figsize=(10,8))
plt.scatter(x_train,y_train,c="red")
plt.plot(x_test,predictions,c="brown")
plt.xlabel("Money spent on radio ads")
plt.ylabel("sales")
plt.show()

# %%
import numpy as np
mse=mean_squared_error(y_test,predictions)
print(f"Mean Squared Error:",mse)
r2=r2_score(y_test,predictions)
print(f"R2-Score:",r2)
rmse=np.sqrt(mse)
print(f"Root Mean Squared Error:",rmse)
# Out:
# Mean Squared Error: 17.84213605964734
# R2-Score: 0.32829210300211775
# Root Mean Squared Error: 4.223995272209398

# %%
x=df['newspaper'].values.reshape(-1,1)
y=df['sales'].values.reshape(-1,1)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print("slope (m) :",model.coef_[0][0])
print("intercept (c) :",model.intercept_[0])
print("the linear model between radio vs sales is y={:.3f}+ {:.3f}x".format(model.intercept_[0],model.coef_[0][0]))
# Out:
# slope (m) : 0.06355483392796399
# intercept (c) : 12.327181954117579
# the linear model between radio vs sales is y=12.327+ 0.064x
